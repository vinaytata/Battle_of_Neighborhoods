# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Bangalore, officially known as Bengaluru, is the capital of the Indian state of Karnataka. It has a population of about 10 million and a metropolitan population of about 8.52 million, making it the third most populous city and fifth most populous urban agglomeration in India. Located in southern India, Bangalore is known for its pleasant climate throughout the year. It is also called the Silicon valley of India. In my present project, I would like to explore the City of Bangalore and find the neighborhood for the people who are trying relocate and also a suitable place for staying based on the amenities around the location.

# %% [markdown]
# ## Data Section <a name="data"></a>

# %% [markdown]
# Data Section:
#
# In my present project of exploring Bangalore, am using a python library called pgeocode (https://github.com/symerio/pgeocode) which is a high-performance off-line querying of GPS coordinates, region name and municipality name from postal codes. Distances between postal codes as well as general distance queries are also supported. GeoNames database includes postal codes for 83 countries. I used ' index postal_codes' function which creates a data frame of unique postal codes of a given country. The data frame consists of following columns:
#
# - country code: iso country code, 2 characters
# - postal code: postal code
# - place name: place name (Ex: District, City etc)
# - state_name: 1. order subdivision (state)
# - state_code: 1. order subdivision (state)
# - county_name: 2. order subdivision (county/province)
# - county_code: 2. order subdivision (county/province)
# - community_name: 3. order subdivision (community)
# - community_code: 3. order subdivision (community)
# - latitude: estimated latitude (wgs84)
# - longitude: estimated longitude (wgs84)
# - accuracy: accuracy of lat/lng from 1=estimated to 6=centroid
#
# I will be using above data to find the suitable location preferences and their respective facilities available.
#
# Also, I will be using Foursquare Location data to get the most common venues of given area in Bengaluru and use python folium library to visualize geographic details of Bengaluru and its places.

# %%
# !pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading https://files.pythonhosted.org/packages/86/44/519e3db3db84acdeb29e24f2e65991960f13464279b61bde5e9e96909c9d/pgeocode-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (1.15.4)
# Requirement already satisfied: pandas in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (0.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2020.6.20)
# Requirement already satisfied: pytz>=2011k in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2.7.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->pgeocode) (1.12.0)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.2.1

# %%
import pgeocode
import pandas as pd
import requests

from geopy.geocoders import Nominatim 

# !conda install -c conda-forge folium=0.5.0  
import folium 
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_0        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
nomi = pgeocode.Nominatim('in')
nomi.query_postal_code("560076")
# Out:
# postal_code                                                  560076
# country code                                                     IN
# place_name        Mico Layout, JP Nagar VIII phase, Mount St Jos...
# state_name                                                Karnataka
# state_code                                                       19
# county_name                                               Bengaluru
# county_code                                                     583
# community_name                                      Bangalore South
# community_code                                                  NaN
# latitude                                                    12.9833
# longitude                                                   77.5833
# accuracy                                                          4
# Name: 0, dtype: object

# %% [markdown]
# ### Lets get the different areas of Bengaluru

# %%
India = nomi._get_data('in')
india = nomi._index_postal_codes()
karnataka = india[india.state_name == "Karnataka"]
bengaluru = karnataka[karnataka.county_name == "Bengaluru"]
bengaluru.head()
# Out:
#       country code postal_code  \
# 10165           IN      560001
# 10166           IN      560002
# 10167           IN      560003
# 10168           IN      560004
# 10169           IN      560005
#
#                                               place_name state_name  \
# 10165  HighCourt, Vasanthanagar, Mahatma Gandhi Road,...  Karnataka
# 10166     Bangalore City, Bangalore Corporation Building  Karnataka
# 10167  Malleswaram, Palace Guttahalli, Swimming Pool ...  Karnataka
# 10168  Gavipuram Extension, Mavalli, Basavanagudi H.O...  Karnataka
# 10169                                        Fraser Town  Karnataka
#
#        state_code county_name  county_code   community_name  community_code  \
# 10165          19   Bengaluru        583.0  Bangalore North             NaN
# 10166          19   Bengaluru        583.0  Bangalore North             NaN
# 10167          19   Bengaluru        583.0  Bangalore North             NaN
# 10168          19   Bengaluru        583.0  Bangalore South             NaN
# 10169          19   Bengaluru        583.0  Bangalore North             NaN
#
#        latitude  longitude  accuracy
# 10165   12.9914  77.592244         3
# 10166   13.2257  77.584350         4
# 10167   13.2257  77.567350         4
# 10168   12.9833  77.583300         1
# 10169   12.9910  77.584300         1

# %%
bengaluru.shape
# Out:
# (107, 12)

# %%
bengaluru.reset_index(inplace = True)
bengaluru.columns
# Out:
# Index(['index', 'country code', 'postal_code', 'place_name', 'state_name',
#        'state_code', 'county_name', 'county_code', 'community_name',
#        'community_code', 'latitude', 'longitude', 'accuracy'],
#       dtype='object')

# %% [markdown]
# ### Getting the required Columns

# %%
bengaluru = bengaluru[['postal_code','place_name', 'community_name', 'latitude', 'longitude']]
bengaluru.head(10)
# Out:
#   postal_code                                         place_name  \
# 0      560001  HighCourt, Vasanthanagar, Mahatma Gandhi Road,...
# 1      560002     Bangalore City, Bangalore Corporation Building
# 2      560003  Malleswaram, Palace Guttahalli, Swimming Pool ...
# 3      560004  Gavipuram Extension, Mavalli, Basavanagudi H.O...
# 4      560005                                        Fraser Town
# 5      560006                    Training Command IAF, J.C.Nagar
# 6      560007                          Air Force Hospital, Agram
# 7      560008                  H.A.L II Stage H.O, Hulsur Bazaar
# 8      560009            K. G. Road, Bangalore Dist Offices Bldg
# 9      560010  Industrial Estate (Bangalore), Rajajinagar H.O...
#
#     community_name  latitude  longitude
# 0  Bangalore North   12.9914  77.592244
# 1  Bangalore North   13.2257  77.584350
# 2  Bangalore North   13.2257  77.567350
# 3  Bangalore South   12.9833  77.583300
# 4  Bangalore North   12.9910  77.584300
# 5  Bangalore North   12.9910  77.584300
# 6  Bangalore North   12.9910  77.584300
# 7  Bangalore North   12.9910  77.584300
# 8  Bangalore North   12.9910  77.584300
# 9  Bangalore North   12.9604  77.567300

# %%
bengaluru.community_name.unique()
# Out:
# array(['Bangalore North', 'Bangalore South', 'Bangalore', 'Bellandur',
#        'Anekal', 'Hosakote', nan, 'Bengaluru', 'Bangaloresouth',
#        'Bg North'], dtype=object)

# %% [markdown]
# ### Grouping the Community names with Unique name

# %%
bengaluru.loc[bengaluru.community_name == 'Bangaloresouth', 'community_name'] = 'Bangalore South'
bengaluru.loc[bengaluru.community_name == 'Bg North', 'community_name'] = 'Bangalore North'

# %%
bengaluru.columns
# Out:
# Index(['postal_code', 'place_name', 'community_name', 'latitude', 'longitude'], dtype='object')

# %% [markdown]
# ### Getting the Latitude and Longitude of Bengaluru

# %%
address = 'Bengaluru, KA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bengaluru are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bengaluru are 12.9791198, 77.5912997.

# %%
# create map of Bengaluru using latitude and longitude values
map_Bengaluru = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, place, community in zip(bengaluru['latitude'], bengaluru['longitude'], bengaluru['place_name'], bengaluru['community_name']):
    label = '{}, {}'.format(community, place)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Bengaluru)  
    
map_Bengaluru
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Getting the count of available postal codes in each Community

# %%
bengaluru.groupby("community_name").count()
# Out:
#                  postal_code  place_name  latitude  longitude
# community_name
# Anekal                     4           4         4          4
# Bangalore                  6           6         6          6
# Bangalore North           59          59        59         59
# Bangalore South           33          33        33         33
# Bellandur                  1           1         1          1
# Bengaluru                  1           1         1          1
# Hosakote                   2           2         2          2

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this section I will be using Forsquare API to get the most common venues of given community of Bengaluru and also used python folium library to visualize geographic details of Bengaluru and its places.
#
# As I am interested in Bangalore South, I decided to just focus on Bengaluru South alone

# %%
#As I am interested in  Bangalore South, I will be using the same for further clustering
blr_south = bengaluru[bengaluru['community_name'] == 'Bangalore South'].reset_index(drop=True)
blr_south.head()
# Out:
#   postal_code                                         place_name  \
# 0      560004  Gavipuram Extension, Mavalli, Basavanagudi H.O...
# 1      560011                  Madhavan Park, Jayangar III Block
# 2      560018               Chamrajpet (Bangalore), Goripalya SO
# 3      560026  Deepanjalinagar, Governmemnt Electric Factory,...
# 4      560027      Wilson Garden, Shanthinagar, Sampangiramnagar
#
#     community_name  latitude  longitude
# 0  Bangalore South   12.9833  77.583300
# 1  Bangalore South   12.9604  77.567300
# 2  Bangalore South   13.2257  77.571150
# 3  Bangalore South   12.9996  77.635900
# 4  Bangalore South   13.2257  77.588467

# %%
#Lets plot Bangalore South Map
address = 'Bangalore South,KA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bangalore South are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bangalore South are 12.862467899999999, 77.56089325971044.

# %%
# create map of Bengaluru using latitude and longitude values
map_blrSouth = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, place, community in zip(blr_south['latitude'], blr_south['longitude'], blr_south['place_name'], blr_south['community_name']):
    label = '{}, {}'.format(community, place)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_blrSouth)  
    
map_blrSouth
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Foursquare
# Now that we have our location coordinates, let's use Foursquare API to get info of Bangalore South neighborhood.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's find the available venues in Bengaluru South:

# %%
blrSouth_venues = getNearbyVenues(names=blr_south['place_name'],
                                   latitudes=blr_south['latitude'],
                                   longitudes=blr_south['longitude']
                                  )
# Out:
# Gavipuram Extension, Mavalli, Basavanagudi H.O, Thyagarajnagar, Pampamahakavi Road
# Madhavan Park, Jayangar III Block
# Chamrajpet (Bangalore), Goripalya SO
# Deepanjalinagar, Governmemnt Electric Factory, Nayandahalli
# Wilson Garden, Shanthinagar, Sampangiramnagar
# Adugodi
# Koramangala I Block, Koramangala, St. John's Medical College, Agara
# Carmelram
# Jayanagar H.O, Jayanagar East, Tilaknagar (Bangalore)
# Viveknagar (Bangalore), Austin Town
# Bidrahalli, Mundur, Bhattarahalli, Virgonagar
# Ashoknagar (Bangalore), State Bank Of Mysore Colony, Dasarahalli(Srinagar), Banashankari
# Chickpet
# Bengaluru Vishwavidyalaya, Mallathahalli
# Rv Niketan
# Chikkalasandra, Subramanyapura
# Doddakallasandra, Konanakunte
# Whitefield, EPIP
# Madivala, Bommanahalli (Bangalore), Singasandra
# Tyagrajnagar, B Sk II Stage, Padmanabhnagar
# Ramohalli, Kumbalgodu Gollahalli, Kumbalagodu
# Mico Layout, JP Nagar VIII phase, Mount St Joseph, Hulimavu, Bannerghatta Road
# J P Nagar, JP Nagar III Phase, Yelachenahalli
# Kathriguppe, Banashankari III Stage, Girinagar (Bangalore)
# Koramangala VI Bk
# Rajarajeshwarinagar, Pattanagere
# Muthanallur, Huskur, Chandapura, Bommasandra Industrial Estate
# Electronics City
# HSR Layout
# Thalaghattapura
# Kumaraswamy Layout
# Bolare, Taralu, Kaggalipura P.O, Thattekuppe, Somanhalli
# Tavarekere (Bangalore), Kadabagere, Chikkanahalli, Sondekoppa, Chunchanakuppe, Soladevanahalli, Kithanahalli

# %%
blrSouth_venues.head(20)
# Out:
#                                          Neighborhood  Neighborhood Latitude  \
# 0   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 1   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 2   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 3   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 4   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 5   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 6   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 7   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 8   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 9   Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 10  Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 11  Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 12  Gavipuram Extension, Mavalli, Basavanagudi H.O...                12.9833
# 13                  Madhavan Park, Jayangar III Block                12.9604
# 14                  Madhavan Park, Jayangar III Block                12.9604
# 15                  Madhavan Park, Jayangar III Block                12.9604
# 16                  Madhavan Park, Jayangar III Block                12.9604
# 17                  Madhavan Park, Jayangar III Block                12.9604
# 18  Deepanjalinagar, Governmemnt Electric Factory,...                12.9996
# 19  Deepanjalinagar, Governmemnt Electric Factory,...                12.9996
#
#     Neighborhood Longitude                 Venue  Venue Latitude  \
# 0                  77.5833          Taj West End       12.984572
# 1                  77.5833   Bangalore Turf Club       12.983914
# 2                  77.5833           Masala Klub       12.984993
# 3                  77.5833                  Mynt       12.984629
# 4                  77.5833       Aromas Of South       12.984895
# 5                  77.5833          The Blue Bar       12.984872
# 6                  77.5833           Blue Ginger       12.984804
# 7                  77.5833          Kabab Studio       12.985325
# 8                  77.5833      Gold Finch Hotel       12.985300
# 9                  77.5833            Sana-di-ge       12.985438
# 10                 77.5833           Atria Hotel       12.980227
# 11                 77.5833     Sreeraj Lassi Bar       12.983183
# 12                 77.5833     Taj West End Pool       12.985403
# 13                 77.5673  Karnataka Bhel House       12.959412
# 14                 77.5673  Davengere Benne Dosa       12.957863
# 15                 77.5673            Food World       12.958802
# 16                 77.5673        Futura Digital       12.957829
# 17                 77.5673        Slv  Fast Food       12.957062
# 18                 77.6359            Orion East       13.001547
# 19                 77.6359             Cinépolis       13.001441
#
#     Venue Longitude         Venue Category
# 0         77.584893                  Hotel
# 1         77.583140              Racetrack
# 2         77.585115      Indian Restaurant
# 3         77.584989            Coffee Shop
# 4         77.580985      Indian Restaurant
# 5         77.583973              Hotel Bar
# 6         77.584045  Vietnamese Restaurant
# 7         77.579465      Indian Restaurant
# 8         77.579475                  Hotel
# 9         77.579605     Seafood Restaurant
# 10        77.586067                  Hotel
# 11        77.587633              Juice Bar
# 12        77.584936             Hotel Pool
# 13        77.567264   Fast Food Restaurant
# 14        77.567354      Indian Restaurant
# 15        77.567083         Shop & Service
# 16        77.568488             Print Shop
# 17        77.567564   Fast Food Restaurant
# 18        77.632619          Shopping Mall
# 19        77.632615              Multiplex

# %%
# Finding unique venue category
print('There are {} uniques categories.'.format(len(blrSouth_venues['Venue Category'].unique())))
# Out:
# There are 48 uniques categories.

# %%
#Let us cluster based on neighborhoods
# one hot encoding
blrSouth_onehot = pd.get_dummies(blrSouth_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
blrSouth_onehot['Neighborhood'] = blrSouth_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [blrSouth_onehot.columns[-1]] + list(blrSouth_onehot.columns[:-1])
blrSouth_onehot = blrSouth_onehot[fixed_columns]

blrSouth_grouped = blrSouth_onehot.groupby('Neighborhood').mean().reset_index()

# %%
blrSouth_grouped.head(20)
# Out:
#                                          Neighborhood   ATM  \
# 0                                             Adugodi  0.00
# 1            Bengaluru Vishwavidyalaya, Mallathahalli  0.00
# 2       Bidrahalli, Mundur, Bhattarahalli, Virgonagar  0.00
# 3                                           Carmelram  0.00
# 4                                            Chickpet  0.00
# 5                      Chikkalasandra, Subramanyapura  0.25
# 6   Deepanjalinagar, Governmemnt Electric Factory,...  0.00
# 7                       Doddakallasandra, Konanakunte  0.25
# 8                                    Electronics City  0.00
# 9   Gavipuram Extension, Mavalli, Basavanagudi H.O...  0.00
# 10      J P Nagar, JP Nagar III Phase, Yelachenahalli  0.00
# 11  Jayanagar H.O, Jayanagar East, Tilaknagar (Ban...  0.00
# 12  Koramangala I Block, Koramangala, St. John's M...  0.20
# 13                                  Koramangala VI Bk  0.00
# 14                                 Kumaraswamy Layout  0.00
# 15                  Madhavan Park, Jayangar III Block  0.00
# 16    Madivala, Bommanahalli (Bangalore), Singasandra  0.00
# 17  Mico Layout, JP Nagar VIII phase, Mount St Jos...  0.00
# 18  Muthanallur, Huskur, Chandapura, Bommasandra I...  0.00
# 19                   Rajarajeshwarinagar, Pattanagere  0.00
#
#     Andhra Restaurant  Art Gallery  Asian Restaurant  Bakery  Bistro  \
# 0            0.000000     0.000000              0.00     0.0    0.00
# 1            0.076923     0.076923              0.00     0.0    0.00
# 2            0.000000     0.000000              0.00     0.0    0.00
# 3            0.000000     0.000000              0.00     0.0    0.00
# 4            0.076923     0.076923              0.00     0.0    0.00
# 5            0.000000     0.000000              0.00     0.0    0.00
# 6            0.000000     0.000000              0.00     0.0    0.00
# 7            0.000000     0.000000              0.00     0.0    0.00
# 8            0.000000     0.000000              0.00     0.0    0.00
# 9            0.000000     0.000000              0.00     0.0    0.00
# 10           0.000000     0.000000              0.00     0.0    0.00
# 11           0.000000     0.000000              0.05     0.0    0.05
# 12           0.000000     0.000000              0.00     0.0    0.00
# 13           0.000000     0.000000              0.00     0.5    0.00
# 14           0.000000     0.000000              0.00     0.0    0.00
# 15           0.000000     0.000000              0.00     0.0    0.00
# 16           0.000000     0.000000              0.00     0.0    0.00
# 17           0.000000     0.000000              0.00     0.0    0.00
# 18           0.000000     0.000000              0.00     0.0    0.00
# 19           0.000000     0.000000              0.00     0.5    0.00
#
#     Boutique  Bus Station      Café  ...  Restaurant  Seafood Restaurant  \
# 0   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 1   0.076923     0.000000  0.153846  ...    0.076923            0.000000
# 2   0.000000     0.000000  0.000000  ...    0.000000            0.076923
# 3   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 4   0.076923     0.000000  0.153846  ...    0.076923            0.000000
# 5   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 6   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 7   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 8   0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 9   0.000000     0.000000  0.000000  ...    0.000000            0.076923
# 10  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 11  0.000000     0.000000  0.050000  ...    0.050000            0.000000
# 12  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 13  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 14  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 15  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 16  0.000000     0.000000  0.000000  ...    0.000000            0.000000
# 17  0.000000     0.000000  0.000000  ...    0.000000            0.076923
# 18  0.000000     0.142857  0.000000  ...    0.000000            0.000000
# 19  0.000000     0.000000  0.000000  ...    0.000000            0.000000
#
#     Shop & Service  Shopping Mall  Smoke Shop  South Indian Restaurant  \
# 0              0.0           0.00        0.00                     0.00
# 1              0.0           0.00        0.00                     0.00
# 2              0.0           0.00        0.00                     0.00
# 3              0.0           0.00        0.00                     0.00
# 4              0.0           0.00        0.00                     0.00
# 5              0.0           0.00        0.00                     0.00
# 6              0.0           0.25        0.00                     0.00
# 7              0.0           0.00        0.00                     0.00
# 8              0.0           0.00        0.00                     0.00
# 9              0.0           0.00        0.00                     0.00
# 10             0.0           0.00        0.25                     0.00
# 11             0.0           0.00        0.00                     0.05
# 12             0.0           0.00        0.00                     0.00
# 13             0.0           0.00        0.00                     0.00
# 14             0.0           0.00        0.00                     0.00
# 15             0.2           0.00        0.00                     0.00
# 16             0.0           0.00        0.00                     0.00
# 17             0.0           0.00        0.00                     0.00
# 18             0.0           0.00        0.00                     0.00
# 19             0.0           0.00        0.00                     0.00
#
#     Supermarket  Theme Park Ride / Attraction  Vietnamese Restaurant  \
# 0           0.0                           0.0               0.000000
# 1           0.0                           0.0               0.000000
# 2           0.0                           0.0               0.076923
# 3           0.0                           0.0               0.000000
# 4           0.0                           0.0               0.000000
# 5           0.0                           0.0               0.000000
# 6           0.0                           0.0               0.000000
# 7           0.0                           0.0               0.000000
# 8           0.0                           0.0               0.000000
# 9           0.0                           0.0               0.076923
# 10          0.0                           0.0               0.000000
# 11          0.0                           0.0               0.000000
# 12          0.2                           0.0               0.000000
# 13          0.0                           0.0               0.000000
# 14          0.0                           0.0               0.000000
# 15          0.0                           0.0               0.000000
# 16          0.0                           0.0               0.000000
# 17          0.0                           0.0               0.076923
# 18          0.0                           0.0               0.000000
# 19          0.0                           0.0               0.000000
#
#     Yoga Studio
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8          0.00
# 9          0.00
# 10         0.00
# 11         0.05
# 12         0.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         0.00
# 19         0.00
#
# [20 rows x 49 columns]

# %%
#Top common venues

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
import numpy as np
num_top_venues = 20

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
blrSouth_venues_sorted = pd.DataFrame(columns=columns)
blrSouth_venues_sorted['Neighborhood'] = blrSouth_grouped['Neighborhood']

for ind in np.arange(blrSouth_grouped.shape[0]):
    blrSouth_venues_sorted.iloc[ind, 1:] = return_most_common_venues(blrSouth_grouped.iloc[ind, :], num_top_venues)

blrSouth_venues_sorted.head(10)
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                            Adugodi                  Farm
# 1           Bengaluru Vishwavidyalaya, Mallathahalli     Indian Restaurant
# 2      Bidrahalli, Mundur, Bhattarahalli, Virgonagar                 Hotel
# 3                                          Carmelram     Convenience Store
# 4                                           Chickpet     Indian Restaurant
# 5                     Chikkalasandra, Subramanyapura                   ATM
# 6  Deepanjalinagar, Governmemnt Electric Factory,...        Clothing Store
# 7                      Doddakallasandra, Konanakunte                   ATM
# 8                                   Electronics City                  Farm
# 9  Gavipuram Extension, Mavalli, Basavanagudi H.O...                 Hotel
#
#   2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 0           Yoga Studio  Vietnamese Restaurant                 Hotel
# 1                  Café                  Hotel            Hotel Pool
# 2     Indian Restaurant     Seafood Restaurant             Hotel Bar
# 3           Yoga Studio  Vietnamese Restaurant                 Hotel
# 4                  Café                  Hotel            Hotel Pool
# 5           Pizza Place      Fish & Chips Shop              Pharmacy
# 6  Fast Food Restaurant          Shopping Mall             Multiplex
# 7           Pizza Place      Fish & Chips Shop              Pharmacy
# 8           Yoga Studio  Vietnamese Restaurant                 Hotel
# 9     Indian Restaurant     Seafood Restaurant             Hotel Bar
#
#    5th Most Common Venue   6th Most Common Venue   7th Most Common Venue  \
# 0             Hookah Bar  Furniture / Home Store       Fish & Chips Shop
# 1           Dance Studio       Andhra Restaurant             Art Gallery
# 2  Vietnamese Restaurant               Juice Bar             Coffee Shop
# 3             Hookah Bar  Furniture / Home Store       Fish & Chips Shop
# 4           Dance Studio       Andhra Restaurant             Art Gallery
# 5             Hookah Bar  Furniture / Home Store    Fast Food Restaurant
# 6            Coffee Shop              Hookah Bar  Furniture / Home Store
# 7             Hookah Bar  Furniture / Home Store    Fast Food Restaurant
# 8             Hookah Bar  Furniture / Home Store       Fish & Chips Shop
# 9  Vietnamese Restaurant               Juice Bar             Coffee Shop
#
#   8th Most Common Venue 9th Most Common Venue  ...  11th Most Common Venue  \
# 0  Fast Food Restaurant   Dumpling Restaurant  ...            Dance Studio
# 1              Boutique            Restaurant  ...  Furniture / Home Store
# 2             Racetrack            Hotel Pool  ...                Boutique
# 3  Fast Food Restaurant                  Farm  ...        Department Store
# 4              Boutique            Restaurant  ...  Furniture / Home Store
# 5                  Farm   Dumpling Restaurant  ...            Dance Studio
# 6     Fish & Chips Shop                  Farm  ...        Department Store
# 7                  Farm   Dumpling Restaurant  ...            Dance Studio
# 8  Fast Food Restaurant   Dumpling Restaurant  ...            Dance Studio
# 9             Racetrack            Hotel Pool  ...                Boutique
#
#   12th Most Common Venue 13th Most Common Venue 14th Most Common Venue  \
# 0      Convenience Store            Coffee Shop         Clothing Store
# 1      Fish & Chips Shop   Fast Food Restaurant                   Farm
# 2      Andhra Restaurant            Art Gallery      Fish & Chips Shop
# 3           Dance Studio            Coffee Shop         Clothing Store
# 4      Fish & Chips Shop   Fast Food Restaurant                   Farm
# 5      Convenience Store            Coffee Shop              Hotel Bar
# 6           Dance Studio      Convenience Store            Yoga Studio
# 7      Convenience Store            Coffee Shop              Hotel Bar
# 8      Convenience Store            Coffee Shop         Clothing Store
# 9      Andhra Restaurant            Art Gallery      Fish & Chips Shop
#
#   15th Most Common Venue 16th Most Common Venue 17th Most Common Venue  \
# 0     Chinese Restaurant                   Café            Bus Station
# 1    Dumpling Restaurant       Department Store     Chinese Restaurant
# 2       Asian Restaurant   Fast Food Restaurant                 Bakery
# 3     Chinese Restaurant                   Café            Bus Station
# 4    Dumpling Restaurant       Department Store     Chinese Restaurant
# 5         Clothing Store     Chinese Restaurant                   Café
# 6              Hotel Bar     Chinese Restaurant                   Café
# 7         Clothing Store     Chinese Restaurant                   Café
# 8     Chinese Restaurant                   Café            Bus Station
# 9       Asian Restaurant   Fast Food Restaurant                 Bakery
#
#   18th Most Common Venue 19th Most Common Venue 20th Most Common Venue
# 0               Boutique                 Bistro                 Bakery
# 1      Convenience Store            Coffee Shop         Clothing Store
# 2                   Farm    Dumpling Restaurant       Department Store
# 3               Boutique                 Bistro                 Bakery
# 4      Convenience Store            Coffee Shop         Clothing Store
# 5            Bus Station               Boutique                 Bistro
# 6            Bus Station               Boutique                 Bistro
# 7            Bus Station               Boutique                 Bistro
# 8               Boutique                 Bistro                 Bakery
# 9                   Farm    Dumpling Restaurant       Department Store
#
# [10 rows x 21 columns]

# %%
# set number of clusters
kclusters = 20

blrSouth_grouped_clustering = blrSouth_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(blrSouth_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:24]
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (13) found smaller than n_clusters (20). Possibly due to duplicate points in X.
#   return_n_iter=True)
# array([ 2, 13, 16,  5, 13,  4,  9,  4,  2, 16,  7,  6,  0,  3,  2, 10,  2,
#        16, 12,  3, 13,  1], dtype=int32)

# %%
# add clustering labels
blrSouth_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

blrSouth_merged = blr_south

blrSouth_merged = blrSouth_merged.join(blrSouth_venues_sorted.set_index('Neighborhood'), on='place_name')

blrSouth_merged.head(10)
# Out:
#   postal_code                                         place_name  \
# 0      560004  Gavipuram Extension, Mavalli, Basavanagudi H.O...
# 1      560011                  Madhavan Park, Jayangar III Block
# 2      560018               Chamrajpet (Bangalore), Goripalya SO
# 3      560026  Deepanjalinagar, Governmemnt Electric Factory,...
# 4      560027      Wilson Garden, Shanthinagar, Sampangiramnagar
# 5      560030                                            Adugodi
# 6      560034  Koramangala I Block, Koramangala, St. John's M...
# 7      560035                                          Carmelram
# 8      560041  Jayanagar H.O, Jayanagar East, Tilaknagar (Ban...
# 9      560047                Viveknagar (Bangalore), Austin Town
#
#     community_name  latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 0  Bangalore South   12.9833  77.583300            16.0                 Hotel
# 1  Bangalore South   12.9604  77.567300            10.0  Fast Food Restaurant
# 2  Bangalore South   13.2257  77.571150             NaN                   NaN
# 3  Bangalore South   12.9996  77.635900             9.0        Clothing Store
# 4  Bangalore South   13.2257  77.588467             NaN                   NaN
# 5  Bangalore South   13.2257  77.575000             2.0                  Farm
# 6  Bangalore South   13.0685  77.641500             0.0                   ATM
# 7  Bangalore South   13.0108  77.749400             5.0     Convenience Store
# 8  Bangalore South   12.9221  77.582033             6.0     Indian Restaurant
# 9  Bangalore South   13.0050  77.321400             NaN                   NaN
#
#   2nd Most Common Venue   3rd Most Common Venue 4th Most Common Venue  ...  \
# 0     Indian Restaurant      Seafood Restaurant             Hotel Bar  ...
# 1            Print Shop       Indian Restaurant        Shop & Service  ...
# 2                   NaN                     NaN                   NaN  ...
# 3  Fast Food Restaurant           Shopping Mall             Multiplex  ...
# 4                   NaN                     NaN                   NaN  ...
# 5           Yoga Studio   Vietnamese Restaurant                 Hotel  ...
# 6           Supermarket  Furniture / Home Store   Dumpling Restaurant  ...
# 7           Yoga Studio   Vietnamese Restaurant                 Hotel  ...
# 8           Coffee Shop             Pizza Place    Chinese Restaurant  ...
# 9                   NaN                     NaN                   NaN  ...
#
#   11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 0               Boutique      Andhra Restaurant            Art Gallery
# 1           Dance Studio      Convenience Store            Coffee Shop
# 2                    NaN                    NaN                    NaN
# 3       Department Store           Dance Studio      Convenience Store
# 4                    NaN                    NaN                    NaN
# 5           Dance Studio      Convenience Store            Coffee Shop
# 6       Department Store           Dance Studio      Convenience Store
# 7       Department Store           Dance Studio            Coffee Shop
# 8             Hookah Bar       Asian Restaurant                 Bistro
# 9                    NaN                    NaN                    NaN
#
#     14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 0        Fish & Chips Shop       Asian Restaurant   Fast Food Restaurant
# 1              Yoga Studio                  Hotel     Chinese Restaurant
# 2                      NaN                    NaN                    NaN
# 3              Yoga Studio              Hotel Bar     Chinese Restaurant
# 4                      NaN                    NaN                    NaN
# 5           Clothing Store     Chinese Restaurant                   Café
# 6           Clothing Store              Hotel Bar                   Café
# 7           Clothing Store     Chinese Restaurant                   Café
# 8  South Indian Restaurant             Restaurant    Dumpling Restaurant
# 9                      NaN                    NaN                    NaN
#
#   17th Most Common Venue 18th Most Common Venue 19th Most Common Venue  \
# 0                 Bakery                   Farm    Dumpling Restaurant
# 1                   Café            Bus Station               Boutique
# 2                    NaN                    NaN                    NaN
# 3                   Café            Bus Station               Boutique
# 4                    NaN                    NaN                    NaN
# 5            Bus Station               Boutique                 Bistro
# 6            Bus Station               Boutique                 Bistro
# 7            Bus Station               Boutique                 Bistro
# 8      Fish & Chips Shop      Andhra Restaurant                   Farm
# 9                    NaN                    NaN                    NaN
#
#   20th Most Common Venue
# 0       Department Store
# 1                 Bistro
# 2                    NaN
# 3                 Bistro
# 4                    NaN
# 5                 Bakery
# 6                 Bakery
# 7                 Bakery
# 8            Art Gallery
# 9                    NaN
#
# [10 rows x 26 columns]

# %%
blrSouth_merged['Cluster Labels'].replace(np.NaN, 0, inplace = True)
blrSouth_merged['Cluster Labels']=blrSouth_merged['Cluster Labels'].astype('int')

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(blrSouth_merged['latitude'], blrSouth_merged['longitude'], blrSouth_merged['community_name'], blrSouth_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# In summary, we have 48 unique categories were returned by Foursquare, then I created a table which shows list of top 20 venue category for each neighbourhood. We have some common venue categories in neighbourhoods. For that reason I used  K-means algorithm to cluster the neighbourhoods. K-Means algorithm is one of the most common cluster methods of unsupervised learning. Hence, I ended the study by visualizing the data and clustering information on the Bengaluru map.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify areas with all the facilities and amenities available for staying in order to aid stakeholders in narrowing down the search for optimal location for a new person relocating to Bengaluru. By finding the venue details from Foursquare data we have first identified the venue categories and for further analysis we found unique venue categories. Clustering of those venues was then performed in order to create areas of common venues.
#
# Final decission on finding the location will be made by stakeholders based on specific characteristics of locations in every recommended zone, taking into consideration additional factors like attractiveness of each location proximity to major roads, real estate availability, prices, social and economic dynamics of every neighborhood etc.
